# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# import citipy module to get the nearest city
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count. 
len(cities)
# Out:
# 757

# %%
# Import requests and api key
import requests
from config import weather_api_key

# %%
# Basic URL
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | yangjiang
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | avera
# Processing Record 6 of Set 1 | akyab
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | sao joao da barra
# Processing Record 12 of Set 1 | beyneu
# Processing Record 13 of Set 1 | asau
# Processing Record 14 of Set 1 | katsuura
# Processing Record 15 of Set 1 | russell
# Processing Record 16 of Set 1 | ternate
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | simbahan
# Processing Record 19 of Set 1 | namibe
# Processing Record 20 of Set 1 | iqaluit
# Processing Record 21 of Set 1 | ponta do sol
# Processing Record 22 of Set 1 | uniontown
# Processing Record 23 of Set 1 | macenta
# Processing Record 24 of Set 1 | vila franca do campo
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | cidreira
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 1 | tuatapere
# Processing Record 30 of Set 1 | acarau
# Processing Record 31 of Set 1 | jasper
# Processing Record 32 of Set 1 | los llanos de aridane
# Processing Record 33 of Set 1 | katy
# Processing Record 34 of Set 1 | arraial do cabo
# Processing Record 35 of Set 1 | ponnani
# Processing Record 36 of Set 1 | alta floresta
# Processing Record 37 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | kozhva
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | north royalton
# Processing Record 42 of Set 1 | laurinburg
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | caravelas
# Processing Record 45 of Set 1 | saldanha
# Processing Record 46 of Set 1 | boffa
# Processing Record 47 of Set 1 | nemuro
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | huai thalaeng
# Processing Record 50 of Set 1 | coihaique
# Processing Record 1 of Set 2 | ancud
# Processing Record 2 of Set 2 | cascais
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | meulaboh
# Processing Record 7 of Set 2 | nago
# Processing Record 8 of Set 2 | vestmannaeyjar
# Processing Record 9 of Set 2 | biak
# Processing Record 10 of Set 2 | vao
# Processing Record 11 of Set 2 | soverato
# Processing Record 12 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 2 | verkh-chebula
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | kahului
# Processing Record 16 of Set 2 | mar del plata
# Processing Record 17 of Set 2 | camacha
# Processing Record 18 of Set 2 | port blair
# Processing Record 19 of Set 2 | lebu
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | rikitea
# Processing Record 22 of Set 2 | necochea
# Processing Record 23 of Set 2 | vila
# Processing Record 24 of Set 2 | geraldton
# Processing Record 25 of Set 2 | ouadda
# Processing Record 26 of Set 2 | parga
# Processing Record 27 of Set 2 | brownsburg
# Processing Record 28 of Set 2 | tazmalt
# Processing Record 29 of Set 2 | carnarvon
# Processing Record 30 of Set 2 | khatanga
# Processing Record 31 of Set 2 | la ronge
# Processing Record 32 of Set 2 | butaritari
# Processing Record 33 of Set 2 | tiksi
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | nanortalik
# Processing Record 36 of Set 2 | karratha
# Processing Record 37 of Set 2 | gatbo
# Processing Record 38 of Set 2 | faya
# Processing Record 39 of Set 2 | konevo
# Processing Record 40 of Set 2 | aswan
# Processing Record 41 of Set 2 | khandbari
# Processing Record 42 of Set 2 | rabo de peixe
# Processing Record 43 of Set 2 | sitka
# Processing Record 44 of Set 2 | kodiak
# Processing Record 45 of Set 2 | staryy nadym
# Processing Record 46 of Set 2 | lagos
# Processing Record 47 of Set 2 | yulara
# Processing Record 48 of Set 2 | rayagada
# Processing Record 49 of Set 2 | vila velha
# Processing Record 50 of Set 2 | mildura
# Processing Record 1 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 3 | hilo
# Processing Record 3 of Set 3 | najran
# Processing Record 4 of Set 3 | khromtau
# Processing Record 5 of Set 3 | asosa
# Processing Record 6 of Set 3 | codrington
# Processing Record 7 of Set 3 | tabuk
# Processing Record 8 of Set 3 | chuy
# Processing Record 9 of Set 3 | san jeronimo
# Processing Record 10 of Set 3 | port hedland
# Processing Record 11 of Set 3 | yellowknife
# Processing Record 12 of Set 3 | bethel
# Processing Record 13 of Set 3 | zeya
# Processing Record 14 of Set 3 | tabialan
# City not found. Skipping...
# Processing Record 15 of Set 3 | grants
# Processing Record 16 of Set 3 | maridi
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 18 of Set 3 | tessalit
# Processing Record 19 of Set 3 | kampot
# Processing Record 20 of Set 3 | nuuk
# Processing Record 21 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 3 | itatskiy
# Processing Record 24 of Set 3 | pisco
# Processing Record 25 of Set 3 | pimentel
# Processing Record 26 of Set 3 | iranshahr
# Processing Record 27 of Set 3 | tasiilaq
# Processing Record 28 of Set 3 | faanui
# Processing Record 29 of Set 3 | thompson
# Processing Record 30 of Set 3 | saint-philippe
# Processing Record 31 of Set 3 | pitimbu
# Processing Record 32 of Set 3 | santa cruz
# Processing Record 33 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 3 | grindavik
# Processing Record 35 of Set 3 | torbay
# Processing Record 36 of Set 3 | kabwe
# Processing Record 37 of Set 3 | ishigaki
# Processing Record 38 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 3 | strezhevoy
# Processing Record 40 of Set 3 | zambezi
# Processing Record 41 of Set 3 | sao filipe
# Processing Record 42 of Set 3 | muros
# Processing Record 43 of Set 3 | hithadhoo
# Processing Record 44 of Set 3 | keti bandar
# Processing Record 45 of Set 3 | champaign
# Processing Record 46 of Set 3 | fortuna
# Processing Record 47 of Set 3 | tsumeb
# Processing Record 48 of Set 3 | rio gallegos
# Processing Record 49 of Set 3 | cabo san lucas
# Processing Record 50 of Set 3 | georgetown
# Processing Record 1 of Set 4 | bonavista
# Processing Record 2 of Set 4 | mirnyy
# Processing Record 3 of Set 4 | arman
# Processing Record 4 of Set 4 | nyurba
# Processing Record 5 of Set 4 | gobabis
# Processing Record 6 of Set 4 | nichinan
# Processing Record 7 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 8 of Set 4 | tabou
# Processing Record 9 of Set 4 | hovd
# Processing Record 10 of Set 4 | mehamn
# Processing Record 11 of Set 4 | quatre cocos
# Processing Record 12 of Set 4 | bac lieu
# Processing Record 13 of Set 4 | sistranda
# Processing Record 14 of Set 4 | kenai
# Processing Record 15 of Set 4 | hirara
# Processing Record 16 of Set 4 | bredasdorp
# Processing Record 17 of Set 4 | port hardy
# Processing Record 18 of Set 4 | saint-augustin
# Processing Record 19 of Set 4 | aldan
# Processing Record 20 of Set 4 | talisay
# Processing Record 21 of Set 4 | haines junction
# Processing Record 22 of Set 4 | san bartolome de tirajana
# Processing Record 23 of Set 4 | pevek
# Processing Record 24 of Set 4 | taoudenni
# Processing Record 25 of Set 4 | nome
# Processing Record 26 of Set 4 | pandan
# Processing Record 27 of Set 4 | kamenskiy
# Processing Record 28 of Set 4 | cherskiy
# Processing Record 29 of Set 4 | kropotkin
# Processing Record 30 of Set 4 | saskylakh
# Processing Record 31 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 4 | cabudare
# Processing Record 34 of Set 4 | aykhal
# Processing Record 35 of Set 4 | airai
# Processing Record 36 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 4 | cayenne
# Processing Record 38 of Set 4 | gimry
# Processing Record 39 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 4 | te anau
# Processing Record 41 of Set 4 | kawalu
# Processing Record 42 of Set 4 | hobart
# Processing Record 43 of Set 4 | bambous virieux
# Processing Record 44 of Set 4 | cravo norte
# Processing Record 45 of Set 4 | forbes
# Processing Record 46 of Set 4 | grand gaube
# Processing Record 47 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 4 | nikolskoye
# Processing Record 49 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 50 of Set 4 | dingle
# Processing Record 1 of Set 5 | azare
# Processing Record 2 of Set 5 | iquitos
# Processing Record 3 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 5 | aklavik
# Processing Record 5 of Set 5 | chumikan
# Processing Record 6 of Set 5 | port alfred
# Processing Record 7 of Set 5 | saint-francois
# Processing Record 8 of Set 5 | kaniama
# Processing Record 9 of Set 5 | jambi
# Processing Record 10 of Set 5 | ibra
# Processing Record 11 of Set 5 | mangaluru
# Processing Record 12 of Set 5 | kavaratti
# Processing Record 13 of Set 5 | kilis
# Processing Record 14 of Set 5 | monster
# Processing Record 15 of Set 5 | kautokeino
# Processing Record 16 of Set 5 | san jose
# Processing Record 17 of Set 5 | esso
# Processing Record 18 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 5 | east london
# Processing Record 20 of Set 5 | xiangxiang
# Processing Record 21 of Set 5 | aasiaat
# Processing Record 22 of Set 5 | puerto ayacucho
# Processing Record 23 of Set 5 | tezu
# Processing Record 24 of Set 5 | lunenburg
# Processing Record 25 of Set 5 | san andres
# Processing Record 26 of Set 5 | kaihua
# Processing Record 27 of Set 5 | somerset
# Processing Record 28 of Set 5 | tuktoyaktuk
# Processing Record 29 of Set 5 | hofn
# Processing Record 30 of Set 5 | tilichiki
# Processing Record 31 of Set 5 | husavik
# Processing Record 32 of Set 5 | huarmey
# Processing Record 33 of Set 5 | tamiahua
# Processing Record 34 of Set 5 | esperance
# Processing Record 35 of Set 5 | wanning
# Processing Record 36 of Set 5 | juifang
# City not found. Skipping...
# Processing Record 37 of Set 5 | khani
# Processing Record 38 of Set 5 | naze
# Processing Record 39 of Set 5 | port elizabeth
# Processing Record 40 of Set 5 | iralaya
# Processing Record 41 of Set 5 | deputatskiy
# Processing Record 42 of Set 5 | mocuba
# Processing Record 43 of Set 5 | shumskiy
# Processing Record 44 of Set 5 | cumberland
# Processing Record 45 of Set 5 | buenos aires
# Processing Record 46 of Set 5 | ajdabiya
# Processing Record 47 of Set 5 | saint anthony
# Processing Record 48 of Set 5 | umea
# Processing Record 49 of Set 5 | gohpur
# Processing Record 50 of Set 5 | eureka
# Processing Record 1 of Set 6 | luderitz
# Processing Record 2 of Set 6 | souillac
# Processing Record 3 of Set 6 | teguise
# Processing Record 4 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 6 | matagami
# Processing Record 6 of Set 6 | sao felix do xingu
# Processing Record 7 of Set 6 | nouadhibou
# Processing Record 8 of Set 6 | olafsvik
# Processing Record 9 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 10 of Set 6 | kloulklubed
# Processing Record 11 of Set 6 | bontang
# Processing Record 12 of Set 6 | singaraja
# Processing Record 13 of Set 6 | toungoo
# City not found. Skipping...
# Processing Record 14 of Set 6 | mersing
# Processing Record 15 of Set 6 | sioux lookout
# Processing Record 16 of Set 6 | bintulu
# Processing Record 17 of Set 6 | narsaq
# Processing Record 18 of Set 6 | tiruchchendur
# Processing Record 19 of Set 6 | gamba
# Processing Record 20 of Set 6 | save
# Processing Record 21 of Set 6 | awjilah
# Processing Record 22 of Set 6 | vardo
# Processing Record 23 of Set 6 | komyshnya
# Processing Record 24 of Set 6 | gao
# Processing Record 25 of Set 6 | vanavara
# Processing Record 26 of Set 6 | tres arroyos
# Processing Record 27 of Set 6 | buloh kasap
# Processing Record 28 of Set 6 | atar
# Processing Record 29 of Set 6 | kutahya
# Processing Record 30 of Set 6 | shirgaon
# Processing Record 31 of Set 6 | gusev
# Processing Record 32 of Set 6 | pierre
# Processing Record 33 of Set 6 | kaitangata
# Processing Record 34 of Set 6 | mao
# Processing Record 35 of Set 6 | cockburn town
# Processing Record 36 of Set 6 | westport
# Processing Record 37 of Set 6 | obluche
# City not found. Skipping...
# Processing Record 38 of Set 6 | hambantota
# Processing Record 39 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 6 | sechura
# Processing Record 41 of Set 6 | mikhaylovka
# Processing Record 42 of Set 6 | svetlogorsk
# Processing Record 43 of Set 6 | dicabisagan
# Processing Record 44 of Set 6 | novochernorechenskiy
# Processing Record 45 of Set 6 | qasigiannguit
# Processing Record 46 of Set 6 | suntar
# Processing Record 47 of Set 6 | portland
# Processing Record 48 of Set 6 | palmer
# Processing Record 49 of Set 6 | san patricio
# Processing Record 50 of Set 6 | kieta
# Processing Record 1 of Set 7 | north platte
# Processing Record 2 of Set 7 | belyy
# Processing Record 3 of Set 7 | longyearbyen
# Processing Record 4 of Set 7 | ribeira grande
# Processing Record 5 of Set 7 | awbari
# Processing Record 6 of Set 7 | surt
# Processing Record 7 of Set 7 | shingu
# Processing Record 8 of Set 7 | saint-pierre
# Processing Record 9 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 7 | hay river
# Processing Record 11 of Set 7 | kintampo
# Processing Record 12 of Set 7 | inverell
# Processing Record 13 of Set 7 | harper
# Processing Record 14 of Set 7 | savannah bight
# Processing Record 15 of Set 7 | yulin
# Processing Record 16 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 7 | mitchell
# Processing Record 18 of Set 7 | upernavik
# Processing Record 19 of Set 7 | la rioja
# Processing Record 20 of Set 7 | bereda
# Processing Record 21 of Set 7 | tullahoma
# Processing Record 22 of Set 7 | la palma
# Processing Record 23 of Set 7 | manzhouli
# Processing Record 24 of Set 7 | hasaki
# Processing Record 25 of Set 7 | penzance
# Processing Record 26 of Set 7 | saint-louis
# Processing Record 27 of Set 7 | green valley
# Processing Record 28 of Set 7 | novikovo
# Processing Record 29 of Set 7 | vlasim
# Processing Record 30 of Set 7 | dakar
# Processing Record 31 of Set 7 | katakwi
# Processing Record 32 of Set 7 | otane
# Processing Record 33 of Set 7 | eyl
# Processing Record 34 of Set 7 | leningradskiy
# Processing Record 35 of Set 7 | abu samrah
# Processing Record 36 of Set 7 | nyuksenitsa
# Processing Record 37 of Set 7 | narrabri
# Processing Record 38 of Set 7 | progreso
# Processing Record 39 of Set 7 | ambilobe
# Processing Record 40 of Set 7 | guadalajara
# Processing Record 41 of Set 7 | talnakh
# Processing Record 42 of Set 7 | wladyslawowo
# Processing Record 43 of Set 7 | solnechnyy
# Processing Record 44 of Set 7 | maceio
# Processing Record 45 of Set 7 | tambura
# Processing Record 46 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 7 | taunggyi
# Processing Record 48 of Set 7 | flinders
# Processing Record 49 of Set 7 | watsa
# Processing Record 50 of Set 7 | mahebourg
# Processing Record 1 of Set 8 | mizdah
# Processing Record 2 of Set 8 | ostrovnoy
# Processing Record 3 of Set 8 | san miguel
# Processing Record 4 of Set 8 | horasan
# Processing Record 5 of Set 8 | mount gambier
# Processing Record 6 of Set 8 | lompoc
# Processing Record 7 of Set 8 | green river
# Processing Record 8 of Set 8 | aqtobe
# Processing Record 9 of Set 8 | dikson
# Processing Record 10 of Set 8 | sterling
# Processing Record 11 of Set 8 | yala
# Processing Record 12 of Set 8 | yar-sale
# Processing Record 13 of Set 8 | cabedelo
# Processing Record 14 of Set 8 | alofi
# Processing Record 15 of Set 8 | krasnoselkup
# Processing Record 16 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 17 of Set 8 | chapais
# Processing Record 18 of Set 8 | sale
# Processing Record 19 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 8 | laguna
# Processing Record 21 of Set 8 | swan hill
# Processing Record 22 of Set 8 | port moresby
# Processing Record 23 of Set 8 | basco
# Processing Record 24 of Set 8 | berlevag
# Processing Record 25 of Set 8 | lerwick
# Processing Record 26 of Set 8 | milyutinskaya
# Processing Record 27 of Set 8 | kyakhta
# Processing Record 28 of Set 8 | guangyuan
# Processing Record 29 of Set 8 | roald
# Processing Record 30 of Set 8 | severo-kurilsk
# Processing Record 31 of Set 8 | capilla de guadalupe
# Processing Record 32 of Set 8 | motygino
# Processing Record 33 of Set 8 | lorengau
# Processing Record 34 of Set 8 | itoman
# Processing Record 35 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 8 | sibolga
# Processing Record 37 of Set 8 | kuopio
# Processing Record 38 of Set 8 | hami
# Processing Record 39 of Set 8 | kruisfontein
# Processing Record 40 of Set 8 | mangan
# Processing Record 41 of Set 8 | muli
# Processing Record 42 of Set 8 | namatanai
# Processing Record 43 of Set 8 | kununurra
# Processing Record 44 of Set 8 | baiyin
# Processing Record 45 of Set 8 | puerto colombia
# Processing Record 46 of Set 8 | nantucket
# Processing Record 47 of Set 8 | ilulissat
# Processing Record 48 of Set 8 | agadir
# Processing Record 49 of Set 8 | sao raimundo das mangabeiras
# Processing Record 50 of Set 8 | maragogi
# Processing Record 1 of Set 9 | yaviza
# Processing Record 2 of Set 9 | dalvik
# Processing Record 3 of Set 9 | baykit
# Processing Record 4 of Set 9 | itarema
# Processing Record 5 of Set 9 | tadpatri
# Processing Record 6 of Set 9 | arlit
# Processing Record 7 of Set 9 | pontianak
# Processing Record 8 of Set 9 | half moon bay
# Processing Record 9 of Set 9 | poum
# Processing Record 10 of Set 9 | urucara
# Processing Record 11 of Set 9 | zemio
# Processing Record 12 of Set 9 | goderich
# Processing Record 13 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 9 | komsomolskiy
# Processing Record 15 of Set 9 | tampakan
# Processing Record 16 of Set 9 | conceicao da barra
# Processing Record 17 of Set 9 | kaoma
# Processing Record 18 of Set 9 | hamilton
# Processing Record 19 of Set 9 | rawson
# Processing Record 20 of Set 9 | colesberg
# Processing Record 21 of Set 9 | saint-georges
# Processing Record 22 of Set 9 | margate
# Processing Record 23 of Set 9 | ucluelet
# Processing Record 24 of Set 9 | olinda
# Processing Record 25 of Set 9 | lyubech
# Processing Record 26 of Set 9 | ust-omchug
# Processing Record 27 of Set 9 | linhares
# Processing Record 28 of Set 9 | satulung
# Processing Record 29 of Set 9 | muisne
# Processing Record 30 of Set 9 | bar harbor
# Processing Record 31 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 32 of Set 9 | pochutla
# Processing Record 33 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 34 of Set 9 | acton vale
# Processing Record 35 of Set 9 | leh
# Processing Record 36 of Set 9 | moerai
# Processing Record 37 of Set 9 | rocha
# Processing Record 38 of Set 9 | bud
# Processing Record 39 of Set 9 | sijunjung
# Processing Record 40 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 41 of Set 9 | thinadhoo
# Processing Record 42 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 9 | vikindu
# Processing Record 44 of Set 9 | pangnirtung
# Processing Record 45 of Set 9 | kavieng
# Processing Record 46 of Set 9 | rumoi
# Processing Record 47 of Set 9 | plettenberg bay
# Processing Record 48 of Set 9 | thunder bay
# Processing Record 49 of Set 9 | makakilo city
# Processing Record 50 of Set 9 | bagdarin
# Processing Record 1 of Set 10 | san-pedro
# Processing Record 2 of Set 10 | northam
# Processing Record 3 of Set 10 | wagar
# Processing Record 4 of Set 10 | aitape
# Processing Record 5 of Set 10 | umm lajj
# Processing Record 6 of Set 10 | sabang
# Processing Record 7 of Set 10 | ixtapa
# Processing Record 8 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 10 | zabrze
# Processing Record 10 of Set 10 | baltasi
# Processing Record 11 of Set 10 | angoram
# Processing Record 12 of Set 10 | elko
# Processing Record 13 of Set 10 | spirovo
# Processing Record 14 of Set 10 | lethem
# Processing Record 15 of Set 10 | yarmouth
# Processing Record 16 of Set 10 | bonthe
# Processing Record 17 of Set 10 | trairi
# Processing Record 18 of Set 10 | constantine
# Processing Record 19 of Set 10 | sananduva
# Processing Record 20 of Set 10 | coquimbo
# Processing Record 21 of Set 10 | victoria
# Processing Record 22 of Set 10 | ocos
# Processing Record 23 of Set 10 | sorland
# Processing Record 24 of Set 10 | mega
# Processing Record 25 of Set 10 | oktyabrskoye
# Processing Record 26 of Set 10 | kamenka
# Processing Record 27 of Set 10 | baruun-urt
# Processing Record 28 of Set 10 | faaa
# Processing Record 29 of Set 10 | teahupoo
# Processing Record 30 of Set 10 | vettavalam
# Processing Record 31 of Set 10 | alice town
# Processing Record 32 of Set 10 | paamiut
# Processing Record 33 of Set 10 | kundiawa
# Processing Record 34 of Set 10 | himeji
# Processing Record 35 of Set 10 | lashio
# Processing Record 36 of Set 10 | bathsheba
# Processing Record 37 of Set 10 | seoul
# Processing Record 38 of Set 10 | salalah
# Processing Record 39 of Set 10 | lata
# Processing Record 40 of Set 10 | west helena
# Processing Record 41 of Set 10 | road town
# Processing Record 42 of Set 10 | baft
# Processing Record 43 of Set 10 | mabaruma
# Processing Record 44 of Set 10 | manggar
# Processing Record 45 of Set 10 | langsa
# Processing Record 46 of Set 10 | amapa
# Processing Record 47 of Set 10 | zhangjiakou
# Processing Record 48 of Set 10 | bousso
# Processing Record 49 of Set 10 | denau
# City not found. Skipping...
# Processing Record 50 of Set 10 | saint johnsbury
# Processing Record 1 of Set 11 | acapulco
# Processing Record 2 of Set 11 | praia da vitoria
# Processing Record 3 of Set 11 | clyde river
# Processing Record 4 of Set 11 | kiama
# Processing Record 5 of Set 11 | amahai
# Processing Record 6 of Set 11 | kupang
# Processing Record 7 of Set 11 | jumla
# Processing Record 8 of Set 11 | maldonado
# Processing Record 9 of Set 11 | villa maria
# Processing Record 10 of Set 11 | bauchi
# Processing Record 11 of Set 11 | mishelevka
# Processing Record 12 of Set 11 | vangaindrano
# Processing Record 13 of Set 11 | cordoba
# Processing Record 14 of Set 11 | mweka
# Processing Record 15 of Set 11 | huilong
# Processing Record 16 of Set 11 | egvekinot
# Processing Record 17 of Set 11 | muncar
# Processing Record 18 of Set 11 | zaysan
# Processing Record 19 of Set 11 | pokhara
# Processing Record 20 of Set 11 | placido de castro
# Processing Record 21 of Set 11 | seymchan
# Processing Record 22 of Set 11 | playas
# Processing Record 23 of Set 11 | havelock
# Processing Record 24 of Set 11 | bilibino
# Processing Record 25 of Set 11 | zhicheng
# Processing Record 26 of Set 11 | lambarene
# Processing Record 27 of Set 11 | medea
# Processing Record 28 of Set 11 | miyang
# Processing Record 29 of Set 11 | tura
# Processing Record 30 of Set 11 | biloela
# Processing Record 31 of Set 11 | omboue
# Processing Record 32 of Set 11 | luganville
# Processing Record 33 of Set 11 | alyangula
# Processing Record 34 of Set 11 | hare bay
# Processing Record 35 of Set 11 | wyndham
# Processing Record 36 of Set 11 | padang
# Processing Record 37 of Set 11 | vaitape
# Processing Record 38 of Set 11 | lavrentiya
# Processing Record 39 of Set 11 | cururupu
# Processing Record 40 of Set 11 | southbridge
# Processing Record 41 of Set 11 | santa catalina
# Processing Record 42 of Set 11 | jinzhou
# Processing Record 43 of Set 11 | nogliki
# Processing Record 44 of Set 11 | okhotsk
# Processing Record 45 of Set 11 | tadine
# Processing Record 46 of Set 11 | venado tuerto
# Processing Record 47 of Set 11 | mogadishu
# Processing Record 48 of Set 11 | mindelo
# Processing Record 49 of Set 11 | taonan
# Processing Record 50 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 12 | dunedin
# Processing Record 2 of Set 12 | auki
# Processing Record 3 of Set 12 | bengkulu
# Processing Record 4 of Set 12 | pangkalanbuun
# Processing Record 5 of Set 12 | ballangen
# Processing Record 6 of Set 12 | genoa
# Processing Record 7 of Set 12 | lawrenceburg
# Processing Record 8 of Set 12 | wewak
# Processing Record 9 of Set 12 | san quintin
# Processing Record 10 of Set 12 | bubaque
# Processing Record 11 of Set 12 | inirida
# Processing Record 12 of Set 12 | cahabon
# Processing Record 13 of Set 12 | yaya
# Processing Record 14 of Set 12 | port-cartier
# Processing Record 15 of Set 12 | dianopolis
# City not found. Skipping...
# Processing Record 16 of Set 12 | tazovskiy
# Processing Record 17 of Set 12 | micheweni
# Processing Record 18 of Set 12 | chignahuapan
# Processing Record 19 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 20 of Set 12 | coahuayana
# Processing Record 21 of Set 12 | north bend
# Processing Record 22 of Set 12 | kon tum
# Processing Record 23 of Set 12 | urumqi
# Processing Record 24 of Set 12 | sisimiut
# Processing Record 25 of Set 12 | sinop
# Processing Record 26 of Set 12 | malkangiri
# Processing Record 27 of Set 12 | mirandopolis
# Processing Record 28 of Set 12 | semey
# Processing Record 29 of Set 12 | trinidad
# Processing Record 30 of Set 12 | kailua
# Processing Record 31 of Set 12 | ekibastuz
# Processing Record 32 of Set 12 | phalombe
# Processing Record 33 of Set 12 | paucartambo
# City not found. Skipping...
# Processing Record 34 of Set 12 | vanimo
# Processing Record 35 of Set 12 | smidovich
# Processing Record 36 of Set 12 | oktyabrskiy
# Processing Record 37 of Set 12 | araouane
# Processing Record 38 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 39 of Set 12 | lagoa
# Processing Record 40 of Set 12 | tapes
# Processing Record 41 of Set 12 | banda aceh
# Processing Record 42 of Set 12 | djenne
# Processing Record 43 of Set 12 | cikampek
# Processing Record 44 of Set 12 | skibbereen
# Processing Record 45 of Set 12 | gravdal
# Processing Record 46 of Set 12 | envira
# Processing Record 47 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 12 | waingapu
# Processing Record 49 of Set 12 | harwich
# Processing Record 50 of Set 12 | searcy
# Processing Record 1 of Set 13 | mareeba
# Processing Record 2 of Set 13 | meilu
# City not found. Skipping...
# Processing Record 3 of Set 13 | urgut
# Processing Record 4 of Set 13 | homer
# Processing Record 5 of Set 13 | xuddur
# Processing Record 6 of Set 13 | marystown
# Processing Record 7 of Set 13 | borba
# Processing Record 8 of Set 13 | diego de almagro
# Processing Record 9 of Set 13 | little chute
# Processing Record 10 of Set 13 | fairbanks
# Processing Record 11 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 13 | clarence town
# Processing Record 13 of Set 13 | kishtwar
# Processing Record 14 of Set 13 | marawi
# Processing Record 15 of Set 13 | beloha
# Processing Record 16 of Set 13 | ayan
# Processing Record 17 of Set 13 | cumana
# Processing Record 18 of Set 13 | great falls
# Processing Record 19 of Set 13 | bossembele
# City not found. Skipping...
# Processing Record 20 of Set 13 | razdolinsk
# Processing Record 21 of Set 13 | nortelandia
# Processing Record 22 of Set 13 | elk city
# Processing Record 23 of Set 13 | nizhniy baskunchak
# Processing Record 24 of Set 13 | tambun
# Processing Record 25 of Set 13 | poshekhonye
# Processing Record 26 of Set 13 | juegang
# Processing Record 27 of Set 13 | sault sainte marie
# Processing Record 28 of Set 13 | yatou
# Processing Record 29 of Set 13 | alice springs
# Processing Record 30 of Set 13 | sao jose da coroa grande
# Processing Record 31 of Set 13 | antsohihy
# Processing Record 32 of Set 13 | snina
# Processing Record 33 of Set 13 | puerto el triunfo
# Processing Record 34 of Set 13 | kasongo
# Processing Record 35 of Set 13 | bhuj
# Processing Record 36 of Set 13 | taburao
# City not found. Skipping...
# Processing Record 37 of Set 13 | kidal
# Processing Record 38 of Set 13 | srednekolymsk
# Processing Record 39 of Set 13 | umm kaddadah
# Processing Record 40 of Set 13 | durban
# Processing Record 41 of Set 13 | klaksvik
# Processing Record 42 of Set 13 | sinnamary
# Processing Record 43 of Set 13 | preobrazheniye
# Processing Record 44 of Set 13 | coos bay
# Processing Record 45 of Set 13 | duz
# City not found. Skipping...
# Processing Record 46 of Set 13 | tieli
# Processing Record 47 of Set 13 | strausberg
# Processing Record 48 of Set 13 | imbituba
# Processing Record 49 of Set 13 | marzuq
# Processing Record 50 of Set 13 | itapirapua
# Processing Record 1 of Set 14 | ostersund
# Processing Record 2 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 3 of Set 14 | arkadak
# Processing Record 4 of Set 14 | kansk
# Processing Record 5 of Set 14 | aksarka
# Processing Record 6 of Set 14 | samarai
# Processing Record 7 of Set 14 | fukuma
# Processing Record 8 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 9 of Set 14 | vestmanna
# Processing Record 10 of Set 14 | saint george
# Processing Record 11 of Set 14 | bara
# Processing Record 12 of Set 14 | srandakan
# Processing Record 13 of Set 14 | hobyo
# Processing Record 14 of Set 14 | beroroha
# Processing Record 15 of Set 14 | hashimoto
# Processing Record 16 of Set 14 | arkhangelsk
# Processing Record 17 of Set 14 | turan
# Processing Record 18 of Set 14 | kelvington
# Processing Record 19 of Set 14 | tetouan
# Processing Record 20 of Set 14 | miracema do tocantins
# Processing Record 21 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 22 of Set 14 | xuanhua
# Processing Record 23 of Set 14 | mandalgovi
# Processing Record 24 of Set 14 | patacamaya
# Processing Record 25 of Set 14 | san cristobal
# Processing Record 26 of Set 14 | muscat
# Processing Record 27 of Set 14 | kapuskasing
# Processing Record 28 of Set 14 | arica
# Processing Record 29 of Set 14 | chippewa falls
# Processing Record 30 of Set 14 | pakdasht
# Processing Record 31 of Set 14 | denpasar
# Processing Record 32 of Set 14 | ipixuna
# Processing Record 33 of Set 14 | ketchikan
# Processing Record 34 of Set 14 | williston
# Processing Record 35 of Set 14 | kirovskiy
# Processing Record 36 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 14 | constitucion
# Processing Record 38 of Set 14 | pandegelang
# Processing Record 39 of Set 14 | elizabeth city
# Processing Record 40 of Set 14 | one hundred mile house
# City not found. Skipping...
# Processing Record 41 of Set 14 | stephenville
# Processing Record 42 of Set 14 | porto novo
# Processing Record 43 of Set 14 | morondava
# Processing Record 44 of Set 14 | alwar
# Processing Record 45 of Set 14 | lujan
# Processing Record 46 of Set 14 | caernarfon
# Processing Record 47 of Set 14 | balabac
# Processing Record 48 of Set 14 | tautira
# Processing Record 49 of Set 14 | boende
# Processing Record 50 of Set 14 | kulhudhuffushi
# Processing Record 1 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 2 of Set 15 | bushehr
# Processing Record 3 of Set 15 | buala
# Processing Record 4 of Set 15 | khash
# Processing Record 5 of Set 15 | tursunzoda
# Processing Record 6 of Set 15 | turukhansk
# Processing Record 7 of Set 15 | ambon
# Processing Record 8 of Set 15 | takoradi
# Processing Record 9 of Set 15 | maumere
# Processing Record 10 of Set 15 | sambava
# Processing Record 11 of Set 15 | pedernales
# Processing Record 12 of Set 15 | edd
# Processing Record 13 of Set 15 | de-kastri
# Processing Record 14 of Set 15 | kattivakkam
# Processing Record 15 of Set 15 | batemans bay
# Processing Record 16 of Set 15 | saulkrasti
# Processing Record 17 of Set 15 | voznesenye
# Processing Record 18 of Set 15 | nikolayevka
# Processing Record 19 of Set 15 | robat karim
# Processing Record 20 of Set 15 | emerald
# Processing Record 21 of Set 15 | nambucca heads
# Processing Record 22 of Set 15 | byron bay
# Processing Record 23 of Set 15 | nizwa
# Processing Record 24 of Set 15 | norman wells
# Processing Record 25 of Set 15 | severnyy
# Processing Record 26 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 27 of Set 15 | olyka
# Processing Record 28 of Set 15 | sitamarhi
# Processing Record 29 of Set 15 | korla
# Processing Record 30 of Set 15 | los arabos
# Processing Record 31 of Set 15 | kalisz
# Processing Record 32 of Set 15 | oranjemund
# Processing Record 33 of Set 15 | chabahar
# Processing Record 34 of Set 15 | igarka
# Processing Record 35 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 36 of Set 15 | bambamarca
# Processing Record 37 of Set 15 | iracoubo
# Processing Record 38 of Set 15 | le port
# Processing Record 39 of Set 15 | uglegorsk
# Processing Record 40 of Set 15 | gubkinskiy
# Processing Record 41 of Set 15 | jinchang
# Processing Record 42 of Set 15 | kerepehi
# Processing Record 43 of Set 15 | chicama
# Processing Record 44 of Set 15 | tecoanapa
# Processing Record 45 of Set 15 | saint-etienne
# Processing Record 46 of Set 15 | almenara
# Processing Record 47 of Set 15 | panorama
# Processing Record 48 of Set 15 | shaoxing
# Processing Record 49 of Set 15 | belmonte
# Processing Record 50 of Set 15 | azangaro
# Processing Record 1 of Set 16 | uribia
# Processing Record 2 of Set 16 | rolim de moura
# City not found. Skipping...
# Processing Record 3 of Set 16 | vuktyl
# Processing Record 4 of Set 16 | pemangkat
# Processing Record 5 of Set 16 | assiniboia
# Processing Record 6 of Set 16 | catamarca
# Processing Record 7 of Set 16 | jinka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.1927  168.8643     44.47        91          84
# 1     Busselton      AU -33.6500  115.3333     54.45        56          94
# 2     Yangjiang      CN  21.8500  111.9667     80.26        89          98
# 3        Albany      US  42.6001  -73.9662     70.09        89          89
# 4         Avera      US  33.1940  -82.5271     94.91        58          56
# 5         Akyab      MM  20.1500   92.9000     79.61        87         100
# 6         Kapaa      US  22.0752 -159.3190     84.52        78          90
# 7         Vaini      TO -21.2000 -175.2000     73.56        83          75
# 8  Punta Arenas      CL -53.1500  -70.9167     42.91        70          40
# 9     Cape Town      ZA -33.9258   18.4232     57.11        82          66
#
#    Wind Speed          Current Description
# 0        2.37                broken clouds
# 1        9.01              overcast clouds
# 2        3.06              overcast clouds
# 3        6.73                   light rain
# 4       13.51                broken clouds
# 5        2.93              overcast clouds
# 6        5.01                   light rain
# 7       21.85  light intensity shower rain
# 8       23.02             scattered clouds
# 9        3.00                broken clouds

# %%
# Create the output file (CSV)
output_data_file = 'WeatherPy_Database.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label= 'City_ID')
